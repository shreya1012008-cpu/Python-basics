# %% [markdown]
# <a href="https://colab.research.google.com/github/shreya1012008-cpu/Python-basics/blob/main/Python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
print("SHREYA")
# Out:
# SHREYA

# %%
name="Shreya"
year="2008"
print("Hello",name)
print(year)
# Out:
# Hello Shreya
# 2008

# %%
name="ammu"
year="2008"
print(name+year)
# Out:
# ammu2008

# %%
a=10
b=24
print("add",a+b)
# Out:
# add 34

# %%
a=53
b=41
print("sub",a-b)
# Out:
# sub 12

# %%
a=24
b=12
print("mul",a*b)
print("div",a/b)
# Out:
# mul 288
# div 2.0

# %%
a=input("Enter your name")
b=input("Enter your branch")
print("Hi",a)
print("My branch is",b)
# Out:
# Enter your nameShreya
# Enter your branchCSE
# Hi Shreya
# My branch is CSE

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a)
print(b)
print(a+b)
# Out:
# Enter the first number13
# Enter the second number25
# 13
# 25
# 38

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a)
print(b)
print(a-b)
# Out:
# Enter the first number34
# Enter the second number12
# 34
# 12
# 22

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a)
print(b)
print(a*b)
# Out:
# Enter the first number12
# Enter the second number24
# 12
# 24
# 288

# %%
a=int(input("Enter the first number"))
b=int(input("Enter the second number"))
print(a)
print(b)
print(a/b)
# Out:
# Enter the first number36
# Enter the second number12
# 36
# 12
# 3.0

# %%
Age=int(input("Enter your age:"))
if Age>=18:
   print("You can vote")
else:
   print("Come again next year")
# Out:
# Enter your age:12
# Come again next year

# %%
Age=int(input("Enter your age:"))
if Age>=18:
   print("You can vote")
else:
   print("Come again next year")
# Out:
# Enter your age:22
# You can vote
